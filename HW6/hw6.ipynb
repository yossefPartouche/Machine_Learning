# %% [markdown]
# # Exercise 6: SVMs, GMMs and EM
#
# ### Make sure that you read and fully understand all the guidelines listed below before you proceed with the exercise.
#
# * HW assignments are a significant part of the learning experience in this course and contribute 50% to your final grade. So, make sure to devote the appropriate time to them.
# * **Sharing solutions with someone who is not your submitting partner is strictly prohibited**. This includes reading someone else's code or sharing your code / posting it somewhere.
# * Appeals regarding submissions that do not follow the guidelines will not be accepted.
#
# ## Read the following instructions carefully:
#
# ### Guidelines for Programming Exercises:
#
# * Complete the required functions in `hw6.py`. Any modifications to this notebook will not be tested by our automated tests.
# * Write **efficient**, **vectorized** code whenever possible. Some calculations in this exercise can take several minutes when implemented efficiently, but will take much longer otherwise. Unnecessary loops will result in point deductions.
# * You are responsible for the correctness of your code. You can add tests to this jupyter notebook to validate your solution. The contents of this jupyter notebook will not be graded or checked.
# * You are allowed to use functions and methods from the [Python Standard Library](https://docs.python.org/3/library/), numpy and pandas only. **Do not import anything else.**
# * Use `numpy` version 1.15.4 or higher.
# * Your code must run without errors. Code that cannot run will not be graded.
# * Include docstrings and comments explaining your code
# * Your code will be tested using automated scripts. So, failure to follow the instructions may lead to test failure, which might significantly affect your grade.
#
#
# ### Submission Guidelines:
# * Submit your solution in a zip file that contains:
#   - The `hw6.py` script with your solution to the progamming exercise
#   - This notebook with your added tests (this is not checked or graded)
#
# * The name of the zip file should contain your ID(s). For example, `hw6_123456789_987654321.zip` if you submitted in pairs and `hw6_123456789.zip` if you submitted the exercise alone.
# * Please use **only a zip** file in your submission.
#
#
# ---
# ---
#
# ## Please sign that you have read and understood the instructions:
#
# ### Yossef Partouche 330072489
# ### Tal Solovey 209954445
#
# ---
# ---

# %% [markdown]
# # Coding Assignment (100 points)
#
# This exercise does not have a theoretical part. In the coding assignment, you will you will train and compare two classifiers for data with a complex distribution:
# 1) A linear classifier: SVM with hinge loss
# 2) A non-linear classifier: Naive Bayes classifier in which the distribution of each feature is modeled using a 1D GMM

# %%
# Setup for Ex 6
import numpy as np
import pandas as pd
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

# make matplotlib figures appear inline in the notebook
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Make the notebook automatically reload external python modules
# %load_ext autoreload
# %autoreload 2
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Reading and exploring the data (0 points)
#
# The dataset you will be analyzing has two features ($x_1$ and $x_2$) and two class labels $y\in{0,1}$. The code block below loads the train and test data and visualizes it using a 2D scatterplot. Notice that the classes appear to be well-separated in the feature space, but not by a linear classifier. The bivaraite distribution of each class also appear to be bi-modal. The univaraite margianl distribution of some features also appears bimodal.

# %%
train_data = pd.read_csv('train_data_shuffled.csv')
test_data = pd.read_csv('test_data_shuffled.csv')
X_train, y_train = train_data[['x1', 'x2']].values, train_data['y'].values
X_test, y_test = test_data[['x1', 'x2']].values, test_data['y'].values

# plot scatter plot of the training data
classes = np.unique(y_train)
n_samples = 1000
# set seed for reproducibility
np.random.seed(42)
random_indices = np.random.choice(len(X_train), n_samples, replace=False)
X_smp = X_train[random_indices, :]
y_smp = y_train[random_indices]

plt.figure(figsize=(7, 5))
for i in range(len(classes)):
    data = X_smp[y_smp == classes[i]]
    plt.scatter(data[:, 0], data[:, 1], label='class={}'.format(i))

plt.title(f'Scatter plot of n={n_samples} instances')
plt.legend()
plt.xlabel('X1')
plt.ylabel('X2')
plt.grid()
plt.show()

# %% [markdown]
# **Stop and think:**
# * What is the expected accuracy of the best linear SVM on such data?
# * What is the expected accuracy of a Naive Bayes classifier using GMMs?

# %% [markdown]
# ## 2. SVM with hinge loss (25 points)
#
#
# Implement the function `compute_hinge_loss_gradients` in the `LinearSVM` class in `hw6.py`.
#
# The `LinearSVM` class implements a linear SVM classifier (without kernel). It finds the classifier's weights by minimzing the hinge loss using (sub)gradient descent. The hinge loss is defined as follows:
# $$
# L(w,w_0;D) ~=~ \frac 12 \|w\|^2 + \frac{C}{n}\sum_{i=1}^n \max\left\{\ 0\ ;\ 1-y^{(i)}\left(w^\top x^{(i)} + w_0\right)\ \right\}~.
# $$
#
# The hyperparameter $C$ controls the slackness (sensitivity to violation of margin constraints and classification errors).
#
# The following methods are already implemented in the `LinearSVM` class:
# * `predict_raw`: computes "raw predictions" before thresholding: $w^\top x^{(i)} + w_0$ for $i=1\ldots n$
# * `predict`: computes predicted class labels
# $\hat{y}^{(i)}=\begin{cases} 1,~~ \text{if}\ w^\top x^{(i)} + w_0 >= 0\\ 0,~~ \text{otherwise}\end{cases}$
# for $i=1\ldots n$.
# * `fit`: fits model parameters. $w,w_0$ by minimizing the hinge loss using gradient descent.
#
# Function `compute_hinge_loss_gradients`, which you are required to implement,
# computes the hinge loss (before udpates) and the gradient of the hinge loss.
# The gradient is specified using an array of length $p$ (`dw`) and a scalar for the bias term (`dw0`).
# This function is called by the function `fit` as part of the gradient descent optimization procedure.
#
# You may implement additional auxiliary functions, as needed, but do not change the code of the methods already implemented.

# %%
from hw6 import LinearSVM
# test lor class on all the data
svm = LinearSVM(C=1, max_iter=100000, learning_rate=0.01)

svm.fit(X_train, y_train, verbose=True)

y_hat_train = svm.predict(X_train)
y_hat_test = svm.predict(X_test)

train_acc = np.mean(y_hat_train.ravel() == y_train.ravel())
test_acc = np.mean(y_hat_test.ravel() == y_test.ravel())

print(f"SVM train set accuracy: {train_acc:.4f}")
print(f"SVM test set accuracy: {test_acc:.4f}")
# Out:
# Iteration 100: Loss = 0.860716
# Iteration 200: Loss = 0.853072
# Iteration 300: Loss = 0.845920
# Iteration 400: Loss = 0.839329
# Iteration 500: Loss = 0.833136
# Iteration 600: Loss = 0.827332
# Iteration 700: Loss = 0.821918
# Iteration 800: Loss = 0.816960
# Iteration 900: Loss = 0.812408
# Iteration 1000: Loss = 0.808250
# Iteration 1100: Loss = 0.804530
# Iteration 1200: Loss = 0.801133
# Iteration 1300: Loss = 0.798018
# Iteration 1400: Loss = 0.795189
# Iteration 1500: Loss = 0.792650
# Iteration 1600: Loss = 0.790372
# Iteration 1700: Loss = 0.788311
# Iteration 1800: Loss = 0.786402
# Iteration 1900: Loss = 0.784698
# Iteration 2000: Loss = 0.783101
# Iteration 2100: Loss = 0.781612
# Iteration 2200: Loss = 0.780219
# Iteration 2300: Loss = 0.778933
# Iteration 2400: Loss = 0.777733
# Iteration 2500: Loss = 0.776645
# Iteration 2600: Loss = 0.775650
# Iteration 2700: Loss = 0.774731
# Iteration 2800: Loss = 0.773897
# Iteration 2900: Loss = 0.773106
# Iteration 3000: Loss = 0.772356
# Iteration 3100: Loss = 0.771676
# Iteration 3200: Loss = 0.771068
# Iteration 3300: Loss = 0.770514
# Iteration 3400: Loss = 0.770007
# Iteration 3500: Loss = 0.769524
# Iteration 3600: Loss = 0.769082
# Iteration 3700: Loss = 0.768670
# Iteration 3800: Loss = 0.768283
# Iteration 3900: Loss = 0.767918
# Iteration 4000: Loss = 0.767600
# Iteration 4100: Loss = 0.767306
# Iteration 4200: Loss = 0.767030
# Iteration 4300: Loss = 0.766784
# Iteration 4400: Loss = 0.766569
# Iteration 4500: Loss = 0.766373
# Iteration 4600: Loss = 0.766190
# Iteration 4700: Loss = 0.766025
# Iteration 4800: Loss = 0.765877
# Iteration 4900: Loss = 0.765740
# Iteration 5000: Loss = 0.765613
# Iteration 5100: Loss = 0.765493
# SVM train set accuracy: 0.8245
# SVM test set accuracy: 0.8130

# %% [markdown]
# ## 3. Set slackness using cross validation (10 points)
#
# We now use 5-fold cross validation (CV) to find a good value for the slackness parameter $C$.
#
# Implement the function `cross_validation` in `hw6.py`.
#
# This function starts by creating a randomly shuffled copy of the dataset and then
# it splits the shuffled copy into `n_folds` blocks of identical size  (this part is already implemented).
# Your implementation should then use this split to implement m-fold cross validation with `n_fold` folds,
# by fitting `n_folds` different versions of the model and computing their accuracy on a different validation block.
# The function returns the average prediction accuracy across of these models.
#
# The function receives a `classifier` object as parameter to use for fitting and evaluation.
# This object should have methods `fit` and `predict` implemented (as in the `LinearSVM` class).
# Since the `fit` method may modify the object, you should create a copy of the object for each fold using the `copy.deepcopy` function.
#
# The code block below uses 5-fold CV to evaluate different vlaues of the slackness hyperparameter ($C$) in the linear SVM.
# It then selects a value for $C$ that results in maximum CV accuracy.

# %%
from hw6 import cross_validation
from hw6 import LinearSVM

C_vals = [0.01, 0.1, 1, 10, 20]
folds = 5

random_state = 1
acc_dict = {}
for C in C_vals:
    svm = LinearSVM(C=C, max_iter=100000)
    acc = cross_validation(X_train, y_train, folds, svm, random_state=random_state)
    acc_dict[C] = acc
    print(f"Accuracy with C={C}:  {acc:.6f}")

best_params = max(acc_dict, key=acc_dict.get)
# Out:
# Iteration 100: Loss = 0.216458
# Iteration 200: Loss = 0.085591
# Iteration 300: Loss = 0.037560
# Iteration 400: Loss = 0.019935
# Iteration 500: Loss = 0.013630
# Iteration 600: Loss = 0.012049
# Iteration 700: Loss = 0.011593
# Iteration 800: Loss = 0.011424
# Iteration 100: Loss = 0.216467
# Iteration 200: Loss = 0.085609
# Iteration 300: Loss = 0.037581
# Iteration 400: Loss = 0.019958
# Iteration 500: Loss = 0.013645
# Iteration 600: Loss = 0.012071
# Iteration 700: Loss = 0.011613
# Iteration 800: Loss = 0.011443
# Iteration 100: Loss = 0.216447
# Iteration 200: Loss = 0.085574
# Iteration 300: Loss = 0.037540
# Iteration 400: Loss = 0.019913
# Iteration 500: Loss = 0.013602
# Iteration 600: Loss = 0.012034
# Iteration 700: Loss = 0.011577
# Iteration 800: Loss = 0.011409
# Iteration 100: Loss = 0.216740
# Iteration 200: Loss = 0.085738
# Iteration 300: Loss = 0.037657
# Iteration 400: Loss = 0.020014
# Iteration 500: Loss = 0.013701
# Iteration 600: Loss = 0.012120
# Iteration 700: Loss = 0.011659
# Iteration 800: Loss = 0.011489
# Iteration 100: Loss = 0.216496
# Iteration 200: Loss = 0.085618
# Iteration 300: Loss = 0.037581
# Iteration 400: Loss = 0.019952
# Iteration 500: Loss = 0.013640
# Iteration 600: Loss = 0.012063
# Iteration 700: Loss = 0.011612
# Accuracy with C=0.01:  0.400000
# Iteration 100: Loss = 0.387807
# Iteration 200: Loss = 0.167514
# Iteration 300: Loss = 0.115121
# Iteration 400: Loss = 0.108301
# Iteration 500: Loss = 0.105675
# Iteration 600: Loss = 0.104587
# Iteration 700: Loss = 0.104065
# Iteration 800: Loss = 0.103750
# Iteration 900: Loss = 0.103511
# Iteration 1000: Loss = 0.103300
# Iteration 1100: Loss = 0.103099
# Iteration 1200: Loss = 0.102901
# Iteration 1300: Loss = 0.102706
# Iteration 1400: Loss = 0.102510
# Iteration 1500: Loss = 0.102315
# Iteration 1600: Loss = 0.102120
# Iteration 1700: Loss = 0.101925
# Iteration 1800: Loss = 0.101730
# Iteration 1900: Loss = 0.101535
# Iteration 2000: Loss = 0.101340
# Iteration 2100: Loss = 0.101145
# Iteration 2200: Loss = 0.100951
# Iteration 2300: Loss = 0.100757
# Iteration 2400: Loss = 0.100563
# Iteration 2500: Loss = 0.100369
# Iteration 2600: Loss = 0.100176
# Iteration 2700: Loss = 0.099983
# Iteration 2800: Loss = 0.099791
# Iteration 2900: Loss = 0.099598
# Iteration 3000: Loss = 0.099406
# Iteration 3100: Loss = 0.099213
# Iteration 3200: Loss = 0.099021
# Iteration 3300: Loss = 0.098830
# Iteration 3400: Loss = 0.098639
# Iteration 3500: Loss = 0.098447
# Iteration 3600: Loss = 0.098256
# Iteration 3700: Loss = 0.098065
# Iteration 3800: Loss = 0.097873
# Iteration 3900: Loss = 0.097682
# Iteration 4000: Loss = 0.097491
# Iteration 4100: Loss = 0.097299
# Iteration 4200: Loss = 0.097108
# Iteration 4300: Loss = 0.096918
# Iteration 4400: Loss = 0.096728
# Iteration 4500: Loss = 0.096539
# Iteration 4600: Loss = 0.096350
# Iteration 4700: Loss = 0.096162
# Iteration 4800: Loss = 0.095975
# Iteration 4900: Loss = 0.095788
# Iteration 5000: Loss = 0.095602
# Iteration 5100: Loss = 0.095417
# Iteration 5200: Loss = 0.095231
# Iteration 5300: Loss = 0.095047
# Iteration 5400: Loss = 0.094862
# Iteration 5500: Loss = 0.094679
# Iteration 5600: Loss = 0.094497
# Iteration 5700: Loss = 0.094317
# Iteration 5800: Loss = 0.094137
# Iteration 5900: Loss = 0.093959
# Iteration 6000: Loss = 0.093780
# Iteration 6100: Loss = 0.093602
# Iteration 6200: Loss = 0.093426
# Iteration 6300: Loss = 0.093250
# Iteration 6400: Loss = 0.093076
# Iteration 6500: Loss = 0.092902
# Iteration 6600: Loss = 0.092730
# Iteration 6700: Loss = 0.092559
# Iteration 6800: Loss = 0.092389
# Iteration 6900: Loss = 0.092220
# Iteration 7000: Loss = 0.092053
# Iteration 7100: Loss = 0.091887
# Iteration 7200: Loss = 0.091722
# Iteration 7300: Loss = 0.091559
# Iteration 7400: Loss = 0.091397
# Iteration 7500: Loss = 0.091237
# Iteration 7600: Loss = 0.091078
# Iteration 7700: Loss = 0.090920
# Iteration 7800: Loss = 0.090764
# Iteration 7900: Loss = 0.090609
# Iteration 8000: Loss = 0.090455
# Iteration 8100: Loss = 0.090303
# Iteration 8200: Loss = 0.090151
# Iteration 8300: Loss = 0.090001
# Iteration 8400: Loss = 0.089853
# Iteration 8500: Loss = 0.089706
# Iteration 8600: Loss = 0.089561
# Iteration 8700: Loss = 0.089416
# Iteration 8800: Loss = 0.089273
# Iteration 8900: Loss = 0.089132
# Iteration 9000: Loss = 0.088992
# Iteration 9100: Loss = 0.088853
# Iteration 9200: Loss = 0.088716
# Iteration 9300: Loss = 0.088580
# Iteration 9400: Loss = 0.088445
# Iteration 9500: Loss = 0.088312
# Iteration 9600: Loss = 0.088181
# Iteration 9700: Loss = 0.088051
# Iteration 9800: Loss = 0.087922
# Iteration 9900: Loss = 0.087794
# Iteration 10000: Loss = 0.087668
# Iteration 10100: Loss = 0.087543
# Iteration 10200: Loss = 0.087420
# Iteration 10300: Loss = 0.087298
# Iteration 10400: Loss = 0.087178
# Iteration 10500: Loss = 0.087058
# Iteration 10600: Loss = 0.086941
# Iteration 10700: Loss = 0.086824
# Iteration 10800: Loss = 0.086709
# Iteration 10900: Loss = 0.086596
# Iteration 11000: Loss = 0.086484
# Iteration 11100: Loss = 0.086372
# Iteration 11200: Loss = 0.086263
# Iteration 11300: Loss = 0.086154
# Iteration 11400: Loss = 0.086047
# Iteration 11500: Loss = 0.085941
# Iteration 11600: Loss = 0.085836
# Iteration 11700: Loss = 0.085733
# Iteration 11800: Loss = 0.085630
# Iteration 11900: Loss = 0.085530
# Iteration 100: Loss = 0.387963
# Iteration 200: Loss = 0.167771
# Iteration 300: Loss = 0.115335
# Iteration 400: Loss = 0.108538
# Iteration 500: Loss = 0.105917
# Iteration 600: Loss = 0.104829
# Iteration 700: Loss = 0.104303
# Iteration 800: Loss = 0.103983
# Iteration 900: Loss = 0.103739
# Iteration 1000: Loss = 0.103523
# Iteration 1100: Loss = 0.103317
# Iteration 1200: Loss = 0.103115
# Iteration 1300: Loss = 0.102914
# Iteration 1400: Loss = 0.102714
# Iteration 1500: Loss = 0.102514
# Iteration 1600: Loss = 0.102314
# Iteration 1700: Loss = 0.102114
# Iteration 1800: Loss = 0.101914
# Iteration 1900: Loss = 0.101714
# Iteration 2000: Loss = 0.101514
# Iteration 2100: Loss = 0.101314
# Iteration 2200: Loss = 0.101115
# Iteration 2300: Loss = 0.100916
# Iteration 2400: Loss = 0.100717
# Iteration 2500: Loss = 0.100519
# Iteration 2600: Loss = 0.100321
# Iteration 2700: Loss = 0.100124
# Iteration 2800: Loss = 0.099926
# Iteration 2900: Loss = 0.099729
# Iteration 3000: Loss = 0.099531
# Iteration 3100: Loss = 0.099335
# Iteration 3200: Loss = 0.099138
# Iteration 3300: Loss = 0.098942
# Iteration 3400: Loss = 0.098746
# Iteration 3500: Loss = 0.098550
# Iteration 3600: Loss = 0.098353
# Iteration 3700: Loss = 0.098157
# Iteration 3800: Loss = 0.097961
# Iteration 3900: Loss = 0.097764
# Iteration 4000: Loss = 0.097569
# Iteration 4100: Loss = 0.097374
# Iteration 4200: Loss = 0.097180
# Iteration 4300: Loss = 0.096987
# Iteration 4400: Loss = 0.096793
# Iteration 4500: Loss = 0.096600
# Iteration 4600: Loss = 0.096409
# Iteration 4700: Loss = 0.096217
# Iteration 4800: Loss = 0.096026
# Iteration 4900: Loss = 0.095836
# Iteration 5000: Loss = 0.095647
# Iteration 5100: Loss = 0.095460
# Iteration 5200: Loss = 0.095273
# Iteration 5300: Loss = 0.095087
# Iteration 5400: Loss = 0.094902
# Iteration 5500: Loss = 0.094717
# Iteration 5600: Loss = 0.094532
# Iteration 5700: Loss = 0.094349
# Iteration 5800: Loss = 0.094166
# Iteration 5900: Loss = 0.093984
# Iteration 6000: Loss = 0.093802
# Iteration 6100: Loss = 0.093621
# Iteration 6200: Loss = 0.093440
# Iteration 6300: Loss = 0.093261
# Iteration 6400: Loss = 0.093084
# Iteration 6500: Loss = 0.092908
# Iteration 6600: Loss = 0.092733
# Iteration 6700: Loss = 0.092559
# Iteration 6800: Loss = 0.092386
# Iteration 6900: Loss = 0.092216
# Iteration 7000: Loss = 0.092046
# Iteration 7100: Loss = 0.091879
# Iteration 7200: Loss = 0.091713
# Iteration 7300: Loss = 0.091548
# Iteration 7400: Loss = 0.091384
# Iteration 7500: Loss = 0.091221
# Iteration 7600: Loss = 0.091060
# Iteration 7700: Loss = 0.090900
# Iteration 7800: Loss = 0.090742
# Iteration 7900: Loss = 0.090585
# Iteration 8000: Loss = 0.090430
# Iteration 8100: Loss = 0.090276
# Iteration 8200: Loss = 0.090123
# Iteration 8300: Loss = 0.089971
# Iteration 8400: Loss = 0.089821
# Iteration 8500: Loss = 0.089672
# Iteration 8600: Loss = 0.089524
# Iteration 8700: Loss = 0.089378
# Iteration 8800: Loss = 0.089233
# Iteration 8900: Loss = 0.089090
# Iteration 9000: Loss = 0.088948
# Iteration 9100: Loss = 0.088808
# Iteration 9200: Loss = 0.088669
# Iteration 9300: Loss = 0.088531
# Iteration 9400: Loss = 0.088395
# Iteration 9500: Loss = 0.088261
# Iteration 9600: Loss = 0.088128
# Iteration 9700: Loss = 0.087996
# Iteration 9800: Loss = 0.087866
# Iteration 9900: Loss = 0.087737
# Iteration 10000: Loss = 0.087609
# Iteration 10100: Loss = 0.087482
# Iteration 10200: Loss = 0.087357
# Iteration 10300: Loss = 0.087232
# Iteration 10400: Loss = 0.087110
# Iteration 10500: Loss = 0.086989
# Iteration 10600: Loss = 0.086869
# Iteration 10700: Loss = 0.086751
# Iteration 10800: Loss = 0.086634
# Iteration 10900: Loss = 0.086519
# Iteration 11000: Loss = 0.086405
# Iteration 11100: Loss = 0.086292
# Iteration 11200: Loss = 0.086181
# Iteration 11300: Loss = 0.086071
# Iteration 11400: Loss = 0.085962
# Iteration 11500: Loss = 0.085854
# Iteration 11600: Loss = 0.085748
# Iteration 11700: Loss = 0.085643
# Iteration 11800: Loss = 0.085539
# Iteration 11900: Loss = 0.085436
# Iteration 12000: Loss = 0.085335
# Iteration 100: Loss = 0.387715
# Iteration 200: Loss = 0.167361
# Iteration 300: Loss = 0.114914
# Iteration 400: Loss = 0.108263
# Iteration 500: Loss = 0.105701
# Iteration 600: Loss = 0.104641
# Iteration 700: Loss = 0.104132
# Iteration 800: Loss = 0.103825
# Iteration 900: Loss = 0.103591
# Iteration 1000: Loss = 0.103386
# Iteration 1100: Loss = 0.103190
# Iteration 1200: Loss = 0.102997
# Iteration 1300: Loss = 0.102806
# Iteration 1400: Loss = 0.102616
# Iteration 1500: Loss = 0.102426
# Iteration 1600: Loss = 0.102236
# Iteration 1700: Loss = 0.102046
# Iteration 1800: Loss = 0.101855
# Iteration 1900: Loss = 0.101665
# Iteration 2000: Loss = 0.101475
# Iteration 2100: Loss = 0.101285
# Iteration 2200: Loss = 0.101095
# Iteration 2300: Loss = 0.100905
# Iteration 2400: Loss = 0.100715
# Iteration 2500: Loss = 0.100525
# Iteration 2600: Loss = 0.100334
# Iteration 2700: Loss = 0.100144
# Iteration 2800: Loss = 0.099954
# Iteration 2900: Loss = 0.099764
# Iteration 3000: Loss = 0.099574
# Iteration 3100: Loss = 0.099385
# Iteration 3200: Loss = 0.099196
# Iteration 3300: Loss = 0.099007
# Iteration 3400: Loss = 0.098818
# Iteration 3500: Loss = 0.098629
# Iteration 3600: Loss = 0.098440
# Iteration 3700: Loss = 0.098251
# Iteration 3800: Loss = 0.098062
# Iteration 3900: Loss = 0.097874
# Iteration 4000: Loss = 0.097685
# Iteration 4100: Loss = 0.097497
# Iteration 4200: Loss = 0.097310
# Iteration 4300: Loss = 0.097122
# Iteration 4400: Loss = 0.096935
# Iteration 4500: Loss = 0.096748
# Iteration 4600: Loss = 0.096562
# Iteration 4700: Loss = 0.096375
# Iteration 4800: Loss = 0.096190
# Iteration 4900: Loss = 0.096007
# Iteration 5000: Loss = 0.095824
# Iteration 5100: Loss = 0.095643
# Iteration 5200: Loss = 0.095462
# Iteration 5300: Loss = 0.095282
# Iteration 5400: Loss = 0.095102
# Iteration 5500: Loss = 0.094924
# Iteration 5600: Loss = 0.094746
# Iteration 5700: Loss = 0.094570
# Iteration 5800: Loss = 0.094394
# Iteration 5900: Loss = 0.094219
# Iteration 6000: Loss = 0.094044
# Iteration 6100: Loss = 0.093869
# Iteration 6200: Loss = 0.093695
# Iteration 6300: Loss = 0.093523
# Iteration 6400: Loss = 0.093352
# Iteration 6500: Loss = 0.093182
# Iteration 6600: Loss = 0.093014
# Iteration 6700: Loss = 0.092847
# Iteration 6800: Loss = 0.092681
# Iteration 6900: Loss = 0.092517
# Iteration 7000: Loss = 0.092354
# Iteration 7100: Loss = 0.092192
# Iteration 7200: Loss = 0.092032
# Iteration 7300: Loss = 0.091874
# Iteration 7400: Loss = 0.091717
# Iteration 7500: Loss = 0.091561
# Iteration 7600: Loss = 0.091406
# Iteration 7700: Loss = 0.091253
# Iteration 7800: Loss = 0.091101
# Iteration 7900: Loss = 0.090951
# Iteration 8000: Loss = 0.090802
# Iteration 8100: Loss = 0.090655
# Iteration 8200: Loss = 0.090509
# Iteration 8300: Loss = 0.090364
# Iteration 8400: Loss = 0.090220
# Iteration 8500: Loss = 0.090077
# Iteration 8600: Loss = 0.089936
# Iteration 8700: Loss = 0.089796
# Iteration 8800: Loss = 0.089657
# Iteration 8900: Loss = 0.089519
# Iteration 9000: Loss = 0.089383
# Iteration 9100: Loss = 0.089247
# Iteration 9200: Loss = 0.089114
# Iteration 9300: Loss = 0.088981
# Iteration 9400: Loss = 0.088850
# Iteration 9500: Loss = 0.088720
# Iteration 9600: Loss = 0.088592
# Iteration 9700: Loss = 0.088464
# Iteration 9800: Loss = 0.088339
# Iteration 9900: Loss = 0.088214
# Iteration 10000: Loss = 0.088091
# Iteration 10100: Loss = 0.087968
# Iteration 10200: Loss = 0.087847
# Iteration 10300: Loss = 0.087727
# Iteration 10400: Loss = 0.087608
# Iteration 10500: Loss = 0.087490
# Iteration 10600: Loss = 0.087374
# Iteration 10700: Loss = 0.087260
# Iteration 10800: Loss = 0.087146
# Iteration 10900: Loss = 0.087034
# Iteration 11000: Loss = 0.086923
# Iteration 11100: Loss = 0.086814
# Iteration 11200: Loss = 0.086706
# Iteration 11300: Loss = 0.086599
# Iteration 11400: Loss = 0.086494
# Iteration 11500: Loss = 0.086390
# Iteration 11600: Loss = 0.086287
# Iteration 11700: Loss = 0.086186
# Iteration 11800: Loss = 0.086085
# Iteration 100: Loss = 0.389600
# Iteration 200: Loss = 0.167557
# Iteration 300: Loss = 0.115397
# Iteration 400: Loss = 0.108319
# Iteration 500: Loss = 0.105585
# Iteration 600: Loss = 0.104446
# Iteration 700: Loss = 0.103891
# Iteration 800: Loss = 0.103551
# Iteration 900: Loss = 0.103290
# Iteration 1000: Loss = 0.103058
# Iteration 1100: Loss = 0.102837
# Iteration 1200: Loss = 0.102619
# Iteration 1300: Loss = 0.102403
# Iteration 1400: Loss = 0.102189
# Iteration 1500: Loss = 0.101975
# Iteration 1600: Loss = 0.101761
# Iteration 1700: Loss = 0.101548
# Iteration 1800: Loss = 0.101335
# Iteration 1900: Loss = 0.101123
# Iteration 2000: Loss = 0.100910
# Iteration 2100: Loss = 0.100697
# Iteration 2200: Loss = 0.100485
# Iteration 2300: Loss = 0.100273
# Iteration 2400: Loss = 0.100062
# Iteration 2500: Loss = 0.099851
# Iteration 2600: Loss = 0.099639
# Iteration 2700: Loss = 0.099428
# Iteration 2800: Loss = 0.099216
# Iteration 2900: Loss = 0.099005
# Iteration 3000: Loss = 0.098793
# Iteration 3100: Loss = 0.098582
# Iteration 3200: Loss = 0.098373
# Iteration 3300: Loss = 0.098164
# Iteration 3400: Loss = 0.097955
# Iteration 3500: Loss = 0.097746
# Iteration 3600: Loss = 0.097537
# Iteration 3700: Loss = 0.097331
# Iteration 3800: Loss = 0.097124
# Iteration 3900: Loss = 0.096918
# Iteration 4000: Loss = 0.096712
# Iteration 4100: Loss = 0.096507
# Iteration 4200: Loss = 0.096303
# Iteration 4300: Loss = 0.096101
# Iteration 4400: Loss = 0.095899
# Iteration 4500: Loss = 0.095698
# Iteration 4600: Loss = 0.095498
# Iteration 4700: Loss = 0.095298
# Iteration 4800: Loss = 0.095099
# Iteration 4900: Loss = 0.094900
# Iteration 5000: Loss = 0.094703
# Iteration 5100: Loss = 0.094506
# Iteration 5200: Loss = 0.094310
# Iteration 5300: Loss = 0.094115
# Iteration 5400: Loss = 0.093921
# Iteration 5500: Loss = 0.093729
# Iteration 5600: Loss = 0.093538
# Iteration 5700: Loss = 0.093349
# Iteration 5800: Loss = 0.093161
# Iteration 5900: Loss = 0.092975
# Iteration 6000: Loss = 0.092790
# Iteration 6100: Loss = 0.092607
# Iteration 6200: Loss = 0.092425
# Iteration 6300: Loss = 0.092245
# Iteration 6400: Loss = 0.092067
# Iteration 6500: Loss = 0.091890
# Iteration 6600: Loss = 0.091714
# Iteration 6700: Loss = 0.091540
# Iteration 6800: Loss = 0.091368
# Iteration 6900: Loss = 0.091197
# Iteration 7000: Loss = 0.091027
# Iteration 7100: Loss = 0.090859
# Iteration 7200: Loss = 0.090692
# Iteration 7300: Loss = 0.090527
# Iteration 7400: Loss = 0.090362
# Iteration 7500: Loss = 0.090199
# Iteration 7600: Loss = 0.090037
# Iteration 7700: Loss = 0.089877
# Iteration 7800: Loss = 0.089718
# Iteration 7900: Loss = 0.089561
# Iteration 8000: Loss = 0.089405
# Iteration 8100: Loss = 0.089251
# Iteration 8200: Loss = 0.089098
# Iteration 8300: Loss = 0.088947
# Iteration 8400: Loss = 0.088798
# Iteration 8500: Loss = 0.088650
# Iteration 8600: Loss = 0.088504
# Iteration 8700: Loss = 0.088359
# Iteration 8800: Loss = 0.088216
# Iteration 8900: Loss = 0.088075
# Iteration 9000: Loss = 0.087935
# Iteration 9100: Loss = 0.087796
# Iteration 9200: Loss = 0.087658
# Iteration 9300: Loss = 0.087523
# Iteration 9400: Loss = 0.087388
# Iteration 9500: Loss = 0.087255
# Iteration 9600: Loss = 0.087123
# Iteration 9700: Loss = 0.086993
# Iteration 9800: Loss = 0.086864
# Iteration 9900: Loss = 0.086736
# Iteration 10000: Loss = 0.086610
# Iteration 10100: Loss = 0.086485
# Iteration 10200: Loss = 0.086362
# Iteration 10300: Loss = 0.086241
# Iteration 10400: Loss = 0.086120
# Iteration 10500: Loss = 0.086002
# Iteration 10600: Loss = 0.085885
# Iteration 10700: Loss = 0.085769
# Iteration 10800: Loss = 0.085654
# Iteration 10900: Loss = 0.085541
# Iteration 11000: Loss = 0.085429
# Iteration 11100: Loss = 0.085319
# Iteration 11200: Loss = 0.085210
# Iteration 11300: Loss = 0.085102
# Iteration 11400: Loss = 0.084995
# Iteration 11500: Loss = 0.084889
# Iteration 11600: Loss = 0.084785
# Iteration 11700: Loss = 0.084682
# Iteration 11800: Loss = 0.084581
# Iteration 100: Loss = 0.388117
# Iteration 200: Loss = 0.167673
# Iteration 300: Loss = 0.115275
# Iteration 400: Loss = 0.108699
# Iteration 500: Loss = 0.106159
# Iteration 600: Loss = 0.105101
# Iteration 700: Loss = 0.104586
# Iteration 800: Loss = 0.104270
# Iteration 900: Loss = 0.104028
# Iteration 1000: Loss = 0.103812
# Iteration 1100: Loss = 0.103606
# Iteration 1200: Loss = 0.103404
# Iteration 1300: Loss = 0.103204
# Iteration 1400: Loss = 0.103003
# Iteration 1500: Loss = 0.102803
# Iteration 1600: Loss = 0.102603
# Iteration 1700: Loss = 0.102403
# Iteration 1800: Loss = 0.102203
# Iteration 1900: Loss = 0.102003
# Iteration 2000: Loss = 0.101803
# Iteration 2100: Loss = 0.101603
# Iteration 2200: Loss = 0.101403
# Iteration 2300: Loss = 0.101203
# Iteration 2400: Loss = 0.101004
# Iteration 2500: Loss = 0.100805
# Iteration 2600: Loss = 0.100606
# Iteration 2700: Loss = 0.100407
# Iteration 2800: Loss = 0.100209
# Iteration 2900: Loss = 0.100012
# Iteration 3000: Loss = 0.099814
# Iteration 3100: Loss = 0.099617
# Iteration 3200: Loss = 0.099419
# Iteration 3300: Loss = 0.099222
# Iteration 3400: Loss = 0.099024
# Iteration 3500: Loss = 0.098827
# Iteration 3600: Loss = 0.098629
# Iteration 3700: Loss = 0.098432
# Iteration 3800: Loss = 0.098234
# Iteration 3900: Loss = 0.098037
# Iteration 4000: Loss = 0.097839
# Iteration 4100: Loss = 0.097642
# Iteration 4200: Loss = 0.097445
# Iteration 4300: Loss = 0.097250
# Iteration 4400: Loss = 0.097055
# Iteration 4500: Loss = 0.096860
# Iteration 4600: Loss = 0.096665
# Iteration 4700: Loss = 0.096471
# Iteration 4800: Loss = 0.096277
# Iteration 4900: Loss = 0.096083
# Iteration 5000: Loss = 0.095891
# Iteration 5100: Loss = 0.095699
# Iteration 5200: Loss = 0.095509
# Iteration 5300: Loss = 0.095320
# Iteration 5400: Loss = 0.095131
# Iteration 5500: Loss = 0.094942
# Iteration 5600: Loss = 0.094755
# Iteration 5700: Loss = 0.094569
# Iteration 5800: Loss = 0.094384
# Iteration 5900: Loss = 0.094200
# Iteration 6000: Loss = 0.094017
# Iteration 6100: Loss = 0.093835
# Iteration 6200: Loss = 0.093653
# Iteration 6300: Loss = 0.093472
# Iteration 6400: Loss = 0.093292
# Iteration 6500: Loss = 0.093113
# Iteration 6600: Loss = 0.092936
# Iteration 6700: Loss = 0.092759
# Iteration 6800: Loss = 0.092583
# Iteration 6900: Loss = 0.092409
# Iteration 7000: Loss = 0.092237
# Iteration 7100: Loss = 0.092066
# Iteration 7200: Loss = 0.091897
# Iteration 7300: Loss = 0.091729
# Iteration 7400: Loss = 0.091563
# Iteration 7500: Loss = 0.091399
# Iteration 7600: Loss = 0.091235
# Iteration 7700: Loss = 0.091073
# Iteration 7800: Loss = 0.090913
# Iteration 7900: Loss = 0.090753
# Iteration 8000: Loss = 0.090596
# Iteration 8100: Loss = 0.090440
# Iteration 8200: Loss = 0.090285
# Iteration 8300: Loss = 0.090131
# Iteration 8400: Loss = 0.089979
# Iteration 8500: Loss = 0.089828
# Iteration 8600: Loss = 0.089679
# Iteration 8700: Loss = 0.089531
# Iteration 8800: Loss = 0.089384
# Iteration 8900: Loss = 0.089239
# Iteration 9000: Loss = 0.089095
# Iteration 9100: Loss = 0.088953
# Iteration 9200: Loss = 0.088812
# Iteration 9300: Loss = 0.088672
# Iteration 9400: Loss = 0.088534
# Iteration 9500: Loss = 0.088397
# Iteration 9600: Loss = 0.088262
# Iteration 9700: Loss = 0.088128
# Iteration 9800: Loss = 0.087996
# Iteration 9900: Loss = 0.087865
# Iteration 10000: Loss = 0.087736
# Iteration 10100: Loss = 0.087608
# Iteration 10200: Loss = 0.087481
# Iteration 10300: Loss = 0.087356
# Iteration 10400: Loss = 0.087232
# Iteration 10500: Loss = 0.087110
# Iteration 10600: Loss = 0.086989
# Iteration 10700: Loss = 0.086869
# Iteration 10800: Loss = 0.086751
# Iteration 10900: Loss = 0.086634
# Iteration 11000: Loss = 0.086517
# Iteration 11100: Loss = 0.086403
# Iteration 11200: Loss = 0.086290
# Iteration 11300: Loss = 0.086178
# Iteration 11400: Loss = 0.086068
# Iteration 11500: Loss = 0.085959
# Iteration 11600: Loss = 0.085851
# Iteration 11700: Loss = 0.085744
# Iteration 11800: Loss = 0.085639
# Iteration 11900: Loss = 0.085534
# Iteration 12000: Loss = 0.085431
# Iteration 12100: Loss = 0.085329
# Accuracy with C=0.1:  0.600000
# Iteration 100: Loss = 0.876718
# Iteration 200: Loss = 0.855764
# Iteration 300: Loss = 0.851804
# Iteration 400: Loss = 0.848031
# Iteration 500: Loss = 0.844439
# Iteration 600: Loss = 0.840948
# Iteration 700: Loss = 0.837547
# Iteration 800: Loss = 0.834274
# Iteration 900: Loss = 0.831142
# Iteration 1000: Loss = 0.828088
# Iteration 1100: Loss = 0.825137
# Iteration 1200: Loss = 0.822310
# Iteration 1300: Loss = 0.819605
# Iteration 1400: Loss = 0.817004
# Iteration 1500: Loss = 0.814497
# Iteration 1600: Loss = 0.812120
# Iteration 1700: Loss = 0.809847
# Iteration 1800: Loss = 0.807679
# Iteration 1900: Loss = 0.805604
# Iteration 2000: Loss = 0.803647
# Iteration 2100: Loss = 0.801812
# Iteration 2200: Loss = 0.800074
# Iteration 2300: Loss = 0.798404
# Iteration 2400: Loss = 0.796805
# Iteration 2500: Loss = 0.795268
# Iteration 2600: Loss = 0.793804
# Iteration 2700: Loss = 0.792409
# Iteration 2800: Loss = 0.791074
# Iteration 2900: Loss = 0.789814
# Iteration 3000: Loss = 0.788603
# Iteration 3100: Loss = 0.787454
# Iteration 3200: Loss = 0.786379
# Iteration 3300: Loss = 0.785363
# Iteration 3400: Loss = 0.784398
# Iteration 3500: Loss = 0.783461
# Iteration 3600: Loss = 0.782559
# Iteration 3700: Loss = 0.781713
# Iteration 3800: Loss = 0.780909
# Iteration 3900: Loss = 0.780127
# Iteration 4000: Loss = 0.779370
# Iteration 4100: Loss = 0.778644
# Iteration 4200: Loss = 0.777944
# Iteration 4300: Loss = 0.777269
# Iteration 4400: Loss = 0.776629
# Iteration 4500: Loss = 0.776011
# Iteration 4600: Loss = 0.775416
# Iteration 4700: Loss = 0.774839
# Iteration 4800: Loss = 0.774282
# Iteration 4900: Loss = 0.773748
# Iteration 5000: Loss = 0.773233
# Iteration 5100: Loss = 0.772740
# Iteration 5200: Loss = 0.772255
# Iteration 5300: Loss = 0.771783
# Iteration 5400: Loss = 0.771335
# Iteration 5500: Loss = 0.770914
# Iteration 5600: Loss = 0.770511
# Iteration 5700: Loss = 0.770117
# Iteration 5800: Loss = 0.769736
# Iteration 5900: Loss = 0.769369
# Iteration 6000: Loss = 0.769007
# Iteration 6100: Loss = 0.768657
# Iteration 6200: Loss = 0.768328
# Iteration 6300: Loss = 0.768017
# Iteration 6400: Loss = 0.767720
# Iteration 6500: Loss = 0.767442
# Iteration 6600: Loss = 0.767178
# Iteration 6700: Loss = 0.766932
# Iteration 6800: Loss = 0.766692
# Iteration 6900: Loss = 0.766458
# Iteration 7000: Loss = 0.766232
# Iteration 7100: Loss = 0.766019
# Iteration 7200: Loss = 0.765817
# Iteration 7300: Loss = 0.765624
# Iteration 7400: Loss = 0.765437
# Iteration 7500: Loss = 0.765257
# Iteration 7600: Loss = 0.765079
# Iteration 7700: Loss = 0.764904
# Iteration 7800: Loss = 0.764733
# Iteration 7900: Loss = 0.764568
# Iteration 8000: Loss = 0.764409
# Iteration 8100: Loss = 0.764262
# Iteration 8200: Loss = 0.764122
# Iteration 8300: Loss = 0.763987
# Iteration 8400: Loss = 0.763857
# Iteration 8500: Loss = 0.763732
# Iteration 8600: Loss = 0.763613
# Iteration 8700: Loss = 0.763498
# Iteration 100: Loss = 0.883717
# Iteration 200: Loss = 0.862825
# Iteration 300: Loss = 0.858839
# Iteration 400: Loss = 0.854998
# Iteration 500: Loss = 0.851303
# Iteration 600: Loss = 0.847706
# Iteration 700: Loss = 0.844268
# Iteration 800: Loss = 0.840948
# Iteration 900: Loss = 0.837696
# Iteration 1000: Loss = 0.834549
# Iteration 1100: Loss = 0.831494
# Iteration 1200: Loss = 0.828547
# Iteration 1300: Loss = 0.825682
# Iteration 1400: Loss = 0.822933
# Iteration 1500: Loss = 0.820318
# Iteration 1600: Loss = 0.817829
# Iteration 1700: Loss = 0.815437
# Iteration 1800: Loss = 0.813145
# Iteration 1900: Loss = 0.810979
# Iteration 2000: Loss = 0.808943
# Iteration 2100: Loss = 0.807036
# Iteration 2200: Loss = 0.805206
# Iteration 2300: Loss = 0.803456
# Iteration 2400: Loss = 0.801775
# Iteration 2500: Loss = 0.800168
# Iteration 2600: Loss = 0.798648
# Iteration 2700: Loss = 0.797208
# Iteration 2800: Loss = 0.795857
# Iteration 2900: Loss = 0.794576
# Iteration 3000: Loss = 0.793353
# Iteration 3100: Loss = 0.792201
# Iteration 3200: Loss = 0.791108
# Iteration 3300: Loss = 0.790070
# Iteration 3400: Loss = 0.789076
# Iteration 3500: Loss = 0.788110
# Iteration 3600: Loss = 0.787188
# Iteration 3700: Loss = 0.786320
# Iteration 3800: Loss = 0.785487
# Iteration 3900: Loss = 0.784669
# Iteration 4000: Loss = 0.783878
# Iteration 4100: Loss = 0.783117
# Iteration 4200: Loss = 0.782377
# Iteration 4300: Loss = 0.781665
# Iteration 4400: Loss = 0.780976
# Iteration 4500: Loss = 0.780302
# Iteration 4600: Loss = 0.779653
# Iteration 4700: Loss = 0.779028
# Iteration 4800: Loss = 0.778423
# Iteration 4900: Loss = 0.777862
# Iteration 5000: Loss = 0.777331
# Iteration 5100: Loss = 0.776823
# Iteration 5200: Loss = 0.776334
# Iteration 5300: Loss = 0.775864
# Iteration 5400: Loss = 0.775407
# Iteration 5500: Loss = 0.774971
# Iteration 5600: Loss = 0.774551
# Iteration 5700: Loss = 0.774141
# Iteration 5800: Loss = 0.773741
# Iteration 5900: Loss = 0.773348
# Iteration 6000: Loss = 0.772975
# Iteration 6100: Loss = 0.772620
# Iteration 6200: Loss = 0.772277
# Iteration 6300: Loss = 0.771944
# Iteration 6400: Loss = 0.771619
# Iteration 6500: Loss = 0.771311
# Iteration 6600: Loss = 0.771016
# Iteration 6700: Loss = 0.770739
# Iteration 6800: Loss = 0.770469
# Iteration 6900: Loss = 0.770212
# Iteration 7000: Loss = 0.769971
# Iteration 7100: Loss = 0.769736
# Iteration 7200: Loss = 0.769507
# Iteration 7300: Loss = 0.769281
# Iteration 7400: Loss = 0.769060
# Iteration 7500: Loss = 0.768845
# Iteration 7600: Loss = 0.768636
# Iteration 7700: Loss = 0.768442
# Iteration 7800: Loss = 0.768261
# Iteration 7900: Loss = 0.768084
# Iteration 8000: Loss = 0.767914
# Iteration 8100: Loss = 0.767752
# Iteration 8200: Loss = 0.767600
# Iteration 8300: Loss = 0.767456
# Iteration 8400: Loss = 0.767320
# Iteration 8500: Loss = 0.767195
# Iteration 8600: Loss = 0.767075
# Iteration 8700: Loss = 0.766958
# Iteration 8800: Loss = 0.766846
# Iteration 8900: Loss = 0.766737
# Iteration 100: Loss = 0.882330
# Iteration 200: Loss = 0.862554
# Iteration 300: Loss = 0.858977
# Iteration 400: Loss = 0.855572
# Iteration 500: Loss = 0.852266
# Iteration 600: Loss = 0.849070
# Iteration 700: Loss = 0.845986
# Iteration 800: Loss = 0.843079
# Iteration 900: Loss = 0.840271
# Iteration 1000: Loss = 0.837533
# Iteration 1100: Loss = 0.834881
# Iteration 1200: Loss = 0.832290
# Iteration 1300: Loss = 0.829767
# Iteration 1400: Loss = 0.827312
# Iteration 1500: Loss = 0.824950
# Iteration 1600: Loss = 0.822693
# Iteration 1700: Loss = 0.820548
# Iteration 1800: Loss = 0.818500
# Iteration 1900: Loss = 0.816522
# Iteration 2000: Loss = 0.814677
# Iteration 2100: Loss = 0.812903
# Iteration 2200: Loss = 0.811203
# Iteration 2300: Loss = 0.809575
# Iteration 2400: Loss = 0.808018
# Iteration 2500: Loss = 0.806554
# Iteration 2600: Loss = 0.805148
# Iteration 2700: Loss = 0.803790
# Iteration 2800: Loss = 0.802490
# Iteration 2900: Loss = 0.801235
# Iteration 3000: Loss = 0.800056
# Iteration 3100: Loss = 0.798943
# Iteration 3200: Loss = 0.797887
# Iteration 3300: Loss = 0.796879
# Iteration 3400: Loss = 0.795911
# Iteration 3500: Loss = 0.794993
# Iteration 3600: Loss = 0.794117
# Iteration 3700: Loss = 0.793275
# Iteration 3800: Loss = 0.792472
# Iteration 3900: Loss = 0.791711
# Iteration 4000: Loss = 0.790993
# Iteration 4100: Loss = 0.790300
# Iteration 4200: Loss = 0.789624
# Iteration 4300: Loss = 0.788972
# Iteration 4400: Loss = 0.788341
# Iteration 4500: Loss = 0.787728
# Iteration 4600: Loss = 0.787133
# Iteration 4700: Loss = 0.786563
# Iteration 4800: Loss = 0.786012
# Iteration 4900: Loss = 0.785479
# Iteration 5000: Loss = 0.784974
# Iteration 5100: Loss = 0.784486
# Iteration 5200: Loss = 0.784013
# Iteration 5300: Loss = 0.783572
# Iteration 5400: Loss = 0.783157
# Iteration 5500: Loss = 0.782761
# Iteration 5600: Loss = 0.782381
# Iteration 5700: Loss = 0.782010
# Iteration 5800: Loss = 0.781662
# Iteration 5900: Loss = 0.781330
# Iteration 6000: Loss = 0.781011
# Iteration 6100: Loss = 0.780704
# Iteration 6200: Loss = 0.780406
# Iteration 6300: Loss = 0.780112
# Iteration 6400: Loss = 0.779831
# Iteration 6500: Loss = 0.779555
# Iteration 6600: Loss = 0.779296
# Iteration 6700: Loss = 0.779057
# Iteration 6800: Loss = 0.778823
# Iteration 6900: Loss = 0.778598
# Iteration 7000: Loss = 0.778384
# Iteration 7100: Loss = 0.778184
# Iteration 7200: Loss = 0.777990
# Iteration 7300: Loss = 0.777809
# Iteration 7400: Loss = 0.777636
# Iteration 7500: Loss = 0.777469
# Iteration 7600: Loss = 0.777306
# Iteration 7700: Loss = 0.777148
# Iteration 7800: Loss = 0.776996
# Iteration 7900: Loss = 0.776853
# Iteration 8000: Loss = 0.776717
# Iteration 8100: Loss = 0.776583
# Iteration 8200: Loss = 0.776452
# Iteration 8300: Loss = 0.776326
# Iteration 8400: Loss = 0.776204
# Iteration 8500: Loss = 0.776087
# Iteration 8600: Loss = 0.775973
# Iteration 100: Loss = 0.873745
# Iteration 200: Loss = 0.854426
# Iteration 300: Loss = 0.850520
# Iteration 400: Loss = 0.846775
# Iteration 500: Loss = 0.843156
# Iteration 600: Loss = 0.839669
# Iteration 700: Loss = 0.836311
# Iteration 800: Loss = 0.833061
# Iteration 900: Loss = 0.829916
# Iteration 1000: Loss = 0.826858
# Iteration 1100: Loss = 0.823903
# Iteration 1200: Loss = 0.821049
# Iteration 1300: Loss = 0.818296
# Iteration 1400: Loss = 0.815648
# Iteration 1500: Loss = 0.813130
# Iteration 1600: Loss = 0.810733
# Iteration 1700: Loss = 0.808427
# Iteration 1800: Loss = 0.806201
# Iteration 1900: Loss = 0.804020
# Iteration 2000: Loss = 0.801942
# Iteration 2100: Loss = 0.800000
# Iteration 2200: Loss = 0.798142
# Iteration 2300: Loss = 0.796366
# Iteration 2400: Loss = 0.794663
# Iteration 2500: Loss = 0.793031
# Iteration 2600: Loss = 0.791484
# Iteration 2700: Loss = 0.790005
# Iteration 2800: Loss = 0.788612
# Iteration 2900: Loss = 0.787314
# Iteration 3000: Loss = 0.786066
# Iteration 3100: Loss = 0.784905
# Iteration 3200: Loss = 0.783808
# Iteration 3300: Loss = 0.782765
# Iteration 3400: Loss = 0.781745
# Iteration 3500: Loss = 0.780769
# Iteration 3600: Loss = 0.779847
# Iteration 3700: Loss = 0.778954
# Iteration 3800: Loss = 0.778085
# Iteration 3900: Loss = 0.777240
# Iteration 4000: Loss = 0.776431
# Iteration 4100: Loss = 0.775653
# Iteration 4200: Loss = 0.774904
# Iteration 4300: Loss = 0.774180
# Iteration 4400: Loss = 0.773483
# Iteration 4500: Loss = 0.772811
# Iteration 4600: Loss = 0.772177
# Iteration 4700: Loss = 0.771582
# Iteration 4800: Loss = 0.771014
# Iteration 4900: Loss = 0.770467
# Iteration 5000: Loss = 0.769933
# Iteration 5100: Loss = 0.769410
# Iteration 5200: Loss = 0.768912
# Iteration 5300: Loss = 0.768451
# Iteration 5400: Loss = 0.768005
# Iteration 5500: Loss = 0.767578
# Iteration 5600: Loss = 0.767174
# Iteration 5700: Loss = 0.766782
# Iteration 5800: Loss = 0.766409
# Iteration 5900: Loss = 0.766057
# Iteration 6000: Loss = 0.765715
# Iteration 6100: Loss = 0.765381
# Iteration 6200: Loss = 0.765057
# Iteration 6300: Loss = 0.764754
# Iteration 6400: Loss = 0.764471
# Iteration 6500: Loss = 0.764201
# Iteration 6600: Loss = 0.763947
# Iteration 6700: Loss = 0.763700
# Iteration 6800: Loss = 0.763464
# Iteration 6900: Loss = 0.763239
# Iteration 7000: Loss = 0.763027
# Iteration 7100: Loss = 0.762823
# Iteration 7200: Loss = 0.762623
# Iteration 7300: Loss = 0.762428
# Iteration 7400: Loss = 0.762237
# Iteration 7500: Loss = 0.762055
# Iteration 7600: Loss = 0.761883
# Iteration 7700: Loss = 0.761719
# Iteration 7800: Loss = 0.761562
# Iteration 7900: Loss = 0.761411
# Iteration 8000: Loss = 0.761265
# Iteration 8100: Loss = 0.761126
# Iteration 8200: Loss = 0.760993
# Iteration 8300: Loss = 0.760867
# Iteration 8400: Loss = 0.760746
# Iteration 100: Loss = 0.889309
# Iteration 200: Loss = 0.867715
# Iteration 300: Loss = 0.863523
# Iteration 400: Loss = 0.859525
# Iteration 500: Loss = 0.855643
# Iteration 600: Loss = 0.851895
# Iteration 700: Loss = 0.848325
# Iteration 800: Loss = 0.844895
# Iteration 900: Loss = 0.841546
# Iteration 1000: Loss = 0.838295
# Iteration 1100: Loss = 0.835162
# Iteration 1200: Loss = 0.832125
# Iteration 1300: Loss = 0.829185
# Iteration 1400: Loss = 0.826373
# Iteration 1500: Loss = 0.823700
# Iteration 1600: Loss = 0.821120
# Iteration 1700: Loss = 0.818637
# Iteration 1800: Loss = 0.816245
# Iteration 1900: Loss = 0.813974
# Iteration 2000: Loss = 0.811827
# Iteration 2100: Loss = 0.809757
# Iteration 2200: Loss = 0.807780
# Iteration 2300: Loss = 0.805915
# Iteration 2400: Loss = 0.804120
# Iteration 2500: Loss = 0.802406
# Iteration 2600: Loss = 0.800750
# Iteration 2700: Loss = 0.799147
# Iteration 2800: Loss = 0.797675
# Iteration 2900: Loss = 0.796279
# Iteration 3000: Loss = 0.794924
# Iteration 3100: Loss = 0.793608
# Iteration 3200: Loss = 0.792364
# Iteration 3300: Loss = 0.791209
# Iteration 3400: Loss = 0.790108
# Iteration 3500: Loss = 0.789051
# Iteration 3600: Loss = 0.788052
# Iteration 3700: Loss = 0.787102
# Iteration 3800: Loss = 0.786183
# Iteration 3900: Loss = 0.785292
# Iteration 4000: Loss = 0.784438
# Iteration 4100: Loss = 0.783607
# Iteration 4200: Loss = 0.782799
# Iteration 4300: Loss = 0.782020
# Iteration 4400: Loss = 0.781271
# Iteration 4500: Loss = 0.780563
# Iteration 4600: Loss = 0.779874
# Iteration 4700: Loss = 0.779211
# Iteration 4800: Loss = 0.778584
# Iteration 4900: Loss = 0.777985
# Iteration 5000: Loss = 0.777407
# Iteration 5100: Loss = 0.776859
# Iteration 5200: Loss = 0.776329
# Iteration 5300: Loss = 0.775817
# Iteration 5400: Loss = 0.775315
# Iteration 5500: Loss = 0.774821
# Iteration 5600: Loss = 0.774341
# Iteration 5700: Loss = 0.773883
# Iteration 5800: Loss = 0.773436
# Iteration 5900: Loss = 0.772997
# Iteration 6000: Loss = 0.772579
# Iteration 6100: Loss = 0.772174
# Iteration 6200: Loss = 0.771784
# Iteration 6300: Loss = 0.771421
# Iteration 6400: Loss = 0.771074
# Iteration 6500: Loss = 0.770737
# Iteration 6600: Loss = 0.770415
# Iteration 6700: Loss = 0.770111
# Iteration 6800: Loss = 0.769816
# Iteration 6900: Loss = 0.769532
# Iteration 7000: Loss = 0.769259
# Iteration 7100: Loss = 0.768994
# Iteration 7200: Loss = 0.768740
# Iteration 7300: Loss = 0.768506
# Iteration 7400: Loss = 0.768280
# Iteration 7500: Loss = 0.768068
# Iteration 7600: Loss = 0.767876
# Iteration 7700: Loss = 0.767690
# Iteration 7800: Loss = 0.767508
# Iteration 7900: Loss = 0.767337
# Iteration 8000: Loss = 0.767174
# Iteration 8100: Loss = 0.767018
# Iteration 8200: Loss = 0.766868
# Iteration 8300: Loss = 0.766722
# Iteration 8400: Loss = 0.766582
# Iteration 8500: Loss = 0.766452
# Accuracy with C=1:  0.822000
# Accuracy with C=10:  0.606500
# Accuracy with C=20:  0.599500

# %%
print(f"Best slackness parameter: C={best_params}")

best_acc = acc_dict[best_params]
print(f"Accuracy with the best parameters: {best_acc:.4f}")
# Out:
# Best slackness parameter: C=1
# Accuracy with the best parameters: 0.8220

# %% [markdown]
# ## 4. Normal distribution and Gaussian mixture model (GMM) (10 points)
#
# We wish to comapre the SVM you trained above with a Naive Bayes classifier based on Gaussian mixture models (GMM). For this purporse, we first have to implement functions for computing the relevant densities.
#
# Implement the functions `norm_pdf` and `gmm_pdf` in `hw6.py`.
#
# Function `norm_pdf` computes the probability density of a normal distribution with given parameters (`mu` and `sigma`) on a vector of real values (`x`).
# Function `gmm_pdf`  computes the probability density of a GMM with given parameters on a vector of real values (`x`).
# Here the parameters are: `weights` (the probability vector $\pi$ for the different Gaussians), `mus` (the means of the different Gaussians) and `sigmas` (the standard deviations of the different Gaussians).
#
# The code block below computes the PDF of a GMM with three mixture components.

# %%
from hw6 import norm_pdf, gmm_pdf
import numpy as np
import pandas as pd
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

#  parameters for a gmm
mus = [0, 2, 8]
sigmas =  [1 , 3,  3]
weights = [0.4, 0.2, 0.3]
weights = weights / np.sum(weights)

# generate a grid of points for plotting the pdf
# the grid should cover the range of the GMM
xx = np.linspace(mus[0]-4*sigmas[0], mus[2]+4*sigmas[2], 100)

# plot the PDF of the GMM and its components
plt.figure(figsize=(10, 5))

prob, _, _= gmm_pdf(xx, weights, mus, sigmas)

plt.plot(xx, prob, label='GMM')
for i in range(len(mus)):
    plt.plot(xx, norm_pdf(xx, mus[i], sigmas[i]), label=f'Gaussian {i+1}', linestyle='--')
plt.title('PDFs of GMM and its components')
plt.legend()
plt.show()

# %% [markdown]
# ## 5. Fit a GMM via Expectation Maximization (EM) (35 points)
#
# Implement the class `GMM` in `hw6.py`.
#
# This class implements an EM algorithm for fitting a one-dimensional (univariate) GMM to a single feature of the data (the feature's marginal distribution).
# Your class should contain the following functions:
# 1. `get_dist_params` - returns a dictionary with the GMM parameters (already implemented; do not modify)
# 1. `init_params` - initializes distribution params (already implemented; do not modify)
# 1. `fit` - learns parameters via the EM algorithm
# 1. `expectation` - calculates responsibilities
# 1. `maximization` - updates GMM parameters based on responsibilities
# 1. `loss` - compute the negative log likelihood (see below)
# 1. `pdf` - returns the PDF of the GMM in a given set of values
#
# Implements the five methods above. You can implement additional functions or add class members, if you think it is useful.
#
# Recall that the parameters of a GMM with $k$ one-dimensional Gaussians are:
# $$
# \theta = (w_1,..,w_k, \mu_1,...,\mu_k, \sigma_1,...,\sigma_k) ~,
# $$
# * $w_j$ is the weight of the $j$-th Gaussian in the mixture (we use $w$ here instead of $\pi$ to avoid confusion with class priors; see (6) below)
# * $\mu_j$ is the mean value of the $j$-th Gaussian
# * $\sigma_j$ is the standard deviation of $j$-th Gaussian
#
# The negative log-likelihood is used as loss for training:
# $$
# J(x; \theta) = \sum_{j=1}^{k}-\log(w_j \cdot \mathcal{N}(x; \mu_j, \sigma_j))
# $$
#
# The code block below fits a univariate GMM to data sampled from the GMM defined in the code block above.

# %%
from hw6 import GMM

# sample (approximately) form the GMM
n_samples = 1000

k = len(mus)
x = np.zeros(n_samples)
for i in range(n_samples):
    j = np.random.choice(k, p=weights)
    xi = mus[j] + sigmas[j] * np.random.randn() 
    x[i] = xi

plt.figure(figsize=(10, 5))
plt.hist(x, bins=100, density=True)
xx = np.linspace(x.min(), x.max(), 100)
# plot the gmm pdf
prob, _, _ = gmm_pdf(xx, weights, mus, sigmas)
plt.plot(xx, prob, label='true GMM pdf')
# fit a gmm to the data
gmm = GMM(k=3, max_iter=10000)
gmm.fit(x)
plt.plot(xx, gmm.pdf(xx), '--r', label='fitted gmm pdf')
plt.legend()
plt.show()

# %% [markdown]
# The code block below fits four GMMs to our training data: one to each class (0,1) and each feature ($x_1,x_2$).
# Each of these GMMs uses $k=2$ Gaussians.

# %%
# now fit a GMM for every feature in every class
# Illustrate the fitted GMMs for each feature in each class over the histogram of the feature
# plot everything using a grid of n_features x n_classes :

n_features = X_train.shape[1]
n_classes = len(np.unique(y_train))
K=2

# Create a grid of subplots
fig, axes = plt.subplots(n_features, n_classes, figsize=(4*n_classes, 4*n_features))

# If only one feature or one class, make axes iterable
if n_features == 1:
    axes = axes.reshape(1, -1)
if n_classes == 1:
    axes = axes.reshape(-1, 1)

# Fit GMM for each feature in each class
for feature_idx in range(n_features):
    for class_idx in range(n_classes):
        # Get data for this feature and class
        mask = (y_train == class_idx)
        feature_data = X_train[mask, feature_idx]
        
        # Fit GMM
        gmm = GMM(k=K, max_iter=1000, eps=0.01)
        gmm.fit(feature_data.reshape(-1, 1))
        
        # Plot histogram of the data
        axes[feature_idx, class_idx].hist(feature_data, bins=50, density=True, alpha=0.7, 
                                         label=f'Class {class_idx} data')
        
        # Plot fitted GMM PDF
        xx = np.linspace(feature_data.min(), feature_data.max(), 100)
        axes[feature_idx, class_idx].plot(xx, gmm.pdf(xx), 'r-', linewidth=2, 
                                         label=f'Fitted GMM')
        
        axes[feature_idx, class_idx].set_title(f'Feature {feature_idx+1}, Class {class_idx}')
        axes[feature_idx, class_idx].legend()
        axes[feature_idx, class_idx].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. GMM naive Bayes classifier (20 points)
#
# Implement the class `NaiveBayesGMM` in `hw6.py`.
#
# This class implements a Naive Bayes classifier which fits a GMM to each (class,feature) combination.
# Your class should contain the following functions:
# 1. `fit` - trains the model by fitting all GMMs using `GMM` objects, as you implemented in (5) above
# 1. `predict` - provides predictions for a given set of samples
#
# Implements the two methods above. You can implement additional functions or add class members, if you think it is useful.
#
# The GMM Naive Bayes classifier should predict classes based on the following MAP rule:
# $$
# \hat{y} = \argmax_j \left\{\pi_j\prod_{t=1}^p GMM_{j,t}(x_t) \right\} ~,
# $$
# where $GMM_{j,t}$ is the PDF of the GMM of class $j$ and feature $t$.
#
# The code block below trains a GMM Naive Bayes classifier on the trianing data and tests it on the test data.

# %%
from hw6 import NaiveBayesGMM

# train a GMM Naive Bayes Classifier
naive_byes = NaiveBayesGMM(k=2)
naive_byes.fit(X_train, y_train)

# evaluate on training and test sets
y_hat_train = naive_byes.predict(X_train)
y_hat_test = naive_byes.predict(X_test)
train_acc = np.mean(y_hat_train.ravel() == y_train.ravel())
test_acc = np.mean(y_hat_test.ravel() == y_test.ravel())
print(f"Naive byes training set accuracy: {train_acc:.4f}")
print(f"Naive byes test set accuracy: {test_acc:.4f}")
# Out:
# Naive byes training set accuracy: 0.9215
# Naive byes test set accuracy: 0.9010

# %% [markdown]
# ## 7. Comparing the two classifiers (0 points)
#
# We now train two different classifiers and compare their performance and decision boundaries.
#
# 1. A SVM classifier with the best $C$ we found earlier
# 1. A GMM Naive Bayes classifier in which each GMM uses a mixture of $k=2$ Gaussians.
#
# The code block below trains the two classifiers, prints their train and test accuracies, and uses the function `plot_decision_regions` to illustrate their decision boundaries.

# %%
from hw6 import LinearSVM, NaiveBayesGMM

def model_score(X, y, cls):
    y_hat = cls.predict(X).ravel()
    return np.mean(y_hat == y.ravel())

def plot_decision_regions(X, y, classifier, resolution=0.01, title=""):
    """
    Plot the decision regions of a classifier.
    """

    # setup marker generator and color map
    markers = ('.', '.')
    colors = ('blue', 'red')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.figure(figsize=(7, 6))
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.title(title)
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')
    plt.show()


svm_cls = LinearSVM(C=best_params)
svm_cls.fit(X_train, y_train)
naive_bayes_cls = NaiveBayesGMM(k=2)
naive_bayes_cls.fit(X_train, y_train)

# evalaute train and test accuracy
svm_train_acc = model_score(X_train, y_train, svm_cls)
svm_test_acc = model_score(X_test, y_test, svm_cls)
naive_bayes_train_acc = model_score(X_train, y_train, naive_bayes_cls)
naive_bayes_test_acc = model_score(X_test, y_test, naive_bayes_cls)

print(f"SVM train accuracy: {svm_train_acc:.4f}")
print(f"SVM test accuracy: {svm_test_acc:.4f}")
print(f"Naive Bayes train accuracy: {naive_bayes_train_acc:.4f}")
print(f"Naive Bayes test accuracy: {naive_bayes_test_acc:.4f}")

plot_decision_regions(X_train, y_train, svm_cls, title="SVM Decision Regions")
plot_decision_regions(X_train, y_train, naive_bayes_cls, title="Naive Bayes Decision Regions")
# Out:
# SVM train accuracy: 0.8195
# SVM test accuracy: 0.8130
# Naive Bayes train accuracy: 0.9215
# Naive Bayes test accuracy: 0.9010
